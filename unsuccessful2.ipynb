# %%
import requests
from bs4 import BeautifulSoup as soup
import time
import datetime
import lxml
import csv

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

# %%
numbers = list(range(1,501))
strnumbers=[str(x) for x in numbers]
url_list=[]
firsturl='https://www.upwork.com/search/profiles/?page=1&q=data%20analyst'
new_url=''
def create_url_list():
    for number in strnumbers:
        listurl=list(firsturl)
        listurl[45]= number
        new_url=''.join(listurl)
        url_list.append(new_url)
    return url_list

# %%
newlist=create_url_list()

# %%
def extract_names():
   
    for link in newlist:
        page = requests.get(link, headers= headers)
        soup1 = soup(page.content, "html.parser")
        soup2 = soup(soup1.prettify(), "html.parser")
        name_list = []
        for name in soup2.findAll('div', {'class':'identity-name'}):
            name_list.append(str(name))
        with open('namesfile.py', 'a')as my_file:
            my_file.write(str(name_list))
            
        
#         big_names.append(name_list)

# %%
extract_names()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp/ipykernel_7916/92761096.py in <module>
# ----> 1 extract_names()
#
# ~\AppData\Local\Temp/ipykernel_7916/3149149673.py in extract_names()
#       3     for link in newlist:
# ----> 4         page = requests.get(link, headers= headers)
#       5         soup1 = soup(page.content, "html.parser")
#
# c:\users\fayez\appdata\local\programs\python\python39-32\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#
# c:\users\fayez\appdata\local\programs\python\python39-32\lib\site-packages\requests\api.py in request(method, url, **kwargs)
# ...

# %%
theurl= 'https://www.upwork.com/search/profiles/?q=data%20analyst'
htmloutputname = 'page.html'
req = requests.get(url, 'html.parser')
with open(htmloutputname, 'w') as f:
    f.write(req.text)
    f.close()

# %%
theurl= 'https://www.upwork.com/search/profiles/?q=data%20analyst'
htmloutputname = 'page.html'
req = requests.get(url, 'html.parser')
with open(htmloutputname, 'w') as f:
    f.write(req.text)
    f.close()
